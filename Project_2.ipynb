# %% [markdown]
# <a href="https://colab.research.google.com/github/ToriStoner/ToriStoner/blob/main/Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import json
import requests

# %%
# API endpoint and parameters
url = "http://api.weatherstack.com/current"
params = {
    "access_key": "8047f607bfcf64ddfe447a793edb44a2",
    "query" : "New York"
}

# Send the request and get the response
response = requests.get(url, params=params)

# %%
weather_data = response.json()

# %%
df = pd.DataFrame(weather_data)
print(df)
# Out:
#                                                  request  \
# type                                                City
# query                 New York, United States of America
# language                                              en
# unit                                                   m
# name                                                 NaN
# country                                              NaN
# region                                               NaN
# lat                                                  NaN
# lon                                                  NaN
# timezone_id                                          NaN
# localtime                                            NaN
# localtime_epoch                                      NaN
# utc_offset                                           NaN
# observation_time                                     NaN
# temperature                                          NaN
# ...

# %%
crime_df = pd.read_csv("/Crime_Data.csv")

# %%
crime_df.head()
# Out:
#    RecordID                          Offense    IncidentID  BlockNumber  \
# 0         1  Assist Citizen - Mental/TDO/ECO  202400034093        900.0
# 1         2    Larceny - Of Veh Parts/Access  202400034075       1600.0
# 2         3                      Hit and Run  202400034071        900.0
# 3         4               Disorderly Conduct  202400034068        900.0
# 4         5               Lost/FoundProperty  202400034047        700.0
#
#         StreetName Agency            DateReported  HourReported  \
# 0   ELLIOTT AVE, A    CPD  2024/10/02 00:24:02+00          2024
# 1    6TH ST SE, 28    CPD  2024/10/01 21:38:47+00          1738
# 2       EMMET ST N    CPD  2024/10/01 21:11:45+00          1711
# 3  ST CLAIR AVE, A    CPD  2024/10/01 20:59:17+00          1659
# 4         RUGBY RD    CPD  2024/10/01 18:23:15+00          1423
#
#   ReportingOfficer
# 0  Venereo, Arturo
# 1     Kirby, Tyree
# 2    Bland, Johnnà
# 3  Prevost, Payten
# 4   Brannon, Devin

# %%
#creating general functions to change the file type

json_data = weather_data
cvs_file = "Crime_Data.csv"

def main():
    input_format = input("Enter input format (json, csv): ").lower()
    output_format = input("Enter output format (json, csv, sql): ").lower()

    if input_format == "json":
        #df = json_to_csv(json_data, csv_file):
        data = json.loads(json_data)
        df = pd.DataFrame(data)
        print(f"Number of rows:({num_rows}")
        print(f"Number of rows:({num_cols}")
        #df = pd.DataFrame(json_data)
        df.dropna(axis=1, inplace=True)
        df.to_csv(csv_file, index=False)
        print(f"JSON data converted to CSV and saved as {csv_file}")
        print(f"Number of rows:({num_rows}")
        print(f"Number of rows:({num_cols}")

    elif output_format == 'sql':
        json_to_sql(json_data, table_name, connection):
        print(f"Number of rows:({num_rows}")
        print(f"Number of rows:({num_cols}")
        df = pd.DataFrame(json_data)
        df.dropna(axis=1, inplace=True)
        df.to_sql(table_name, connection, if_exists='replace',index = False)
        print(f"JSON data converted to sql and saved as {table_name}")
        print(f"Number of rows:({num_rows}")
        print(f"Number of rows:({num_cols}")

    elif input_format == 'csv':
        csv_to_json(csv_file, json_file):
        print(f"Number of rows:({num_rows}")
        print(f"Number of rows:({num_cols}")
        df = pd.read_csv(csv_file)
        df.dropna(axis=1, inplace=True)
        df.to_json(json_file, orient="records")
        print(f"CSV data converted to JSON and saved to {json_file}")
        print(f"Number of rows:({num_rows}")
        print(f"Number of rows:({num_cols}")

    else:
      print("Invalid File Type")
# Out:
#   File "<ipython-input-80-3309b6805d62>", line 24
#     json_to_sql(json_data, table_name, connection):
#                                                   ^
# SyntaxError: invalid syntax

# %%
#new file should be outputted to SQL database

#main()
json_data = weather_data
cvs_file = "Crime_Data."

#How to i get json into a dataframe
#data = json.loads(json_data)
df = pd.DataFrame(json_data)
#print(f"Number of rows:({df.num_rows}")
#print(f"Number of rows:({num_cols}")
df.head(5)
#how do ai get my csv into a dataframe
df = pd.read_csv(cvs_file)
# Out:
#                                      request  location current
# type                                    City       NaN     NaN
# query     New York, United States of America       NaN     NaN
# language                                  en       NaN     NaN
# unit                                       m       NaN     NaN
# name                                     NaN  New York     NaN
