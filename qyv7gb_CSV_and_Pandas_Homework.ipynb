# %% [markdown]
# <a href="https://colab.research.google.com/github/ToriStoner/ToriStoner/blob/main/qyv7gb_CSV_and_Pandas_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
acc_df = pd.read_csv("acc.csv")

# %%
#display first 5 rows of the data frame
acc_df.head(5)
# Out:
#   Unnamed: 0     Unnamed: 1 Unnamed: 2 Unnamed: 3      Unnamed: 4 Totals  \
# 0         Rk         Player      Class        Pos          School      G
# 1          1   Amaree Abram         SO          G    Georgia Tech     10
# 2          2   Sola Adebisi         FR          F   Florida State      7
# 3          3  Prince Aligbe         SO          F  Boston College     35
# 4          4     Abe Atiyeh         SR          G  Boston College      4
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 11 Unnamed: 12  \
# 0         MP        TRB        AST        STL  ...         TOV          PF
# 1        108         17         11          1  ...           9          10
# 2          9          1          1          0  ...           1           1
# 3        651        119         21         15  ...          30          51
# 4          6          0          0          0  ...           1           0
#
#   Unnamed: 13 Shooting Unnamed: 15 Unnamed: 16 Unnamed: 17 Advanced  \
# ...

# %%
acc_df.columns = acc_df.iloc[0]
acc_df = acc_df[1:]

# %%
acc_df.head()
# Out:
# 0 Rk         Player Class Pos          School   G   MP  TRB AST STL  ... TOV  \
# 1  1   Amaree Abram    SO   G    Georgia Tech  10  108   17  11   1  ...   9
# 2  2   Sola Adebisi    FR   F   Florida State   7    9    1   1   0  ...   1
# 3  3  Prince Aligbe    SO   F  Boston College  35  651  119  21  15  ...  30
# 4  4     Abe Atiyeh    SR   G  Boston College   4    6    0   0   0  ...   1
# 5  5    Zack Austin    JR   F      Pittsburgh  33  746  137  29  32  ...  13
#
# 0  PF  PTS    FG%    2P%    3P%    FT%  PER    WS   BPM
# 1  10   34  0.262  0.318    0.2  0.615  4.1  -0.1  -6.4
# 2   1    2    0.5    0.5    NaN    NaN  3.5     0  -6.7
# 3  51  164  0.435  0.522  0.147   0.62  9.4   0.9  -1.3
# 4   0    3  0.333      0      1    NaN  1.1     0  -8.2
# 5  35  216  0.417  0.563  0.295  0.737   18   2.9   7.9
#
# [5 rows x 21 columns]

# %%
#add up the total points scored by all players
#points is stored as a string, have to convert to numeric

acc_df["PTS"] = pd.to_numeric(acc_df["PTS"])


acc_df["MP"] = pd.to_numeric(acc_df["MP"])

# %%
total_points = acc_df["PTS"].sum()
total_points
# Out:
# 38411

# %%
#find the player who has the most minutes

most_minutes = acc_df[['Player', 'MP']].sort_values(by='MP', ascending=False).head(1)
most_minutes
# Out:
# 0           Player    MP
# 136  Casey Morsell  1333

# %%
#Identify the top 5 players for total rebounds
acc_df["TRB"] = pd.to_numeric(acc_df["TRB"])

total_rebounds = acc_df[['Player', 'TRB']].sort_values(by='TRB', ascending=False).head(5)
total_rebounds
# Out:
# 0             Player  TRB
# 6      Armando Bacot  380
# 179  Ian Schieffelin  340
# 91   Harrison Ingram  327
# 45    Mohamed Diarra  311
# 150    Norchad Omier  309

# %%
#create a df containing only players that played more than 500 minutes

new_df = acc_df[acc_df["MP"] > 500]

# %%
new_df.head(5)
# Out:
# 0   Rk         Player Class Pos          School   G    MP  TRB  AST STL  ...  \
# 3    3  Prince Aligbe    SO   F  Boston College  35   651  119   21  15  ...
# 5    5    Zack Austin    JR   F      Pittsburgh  33   746  137   29  32  ...
# 6    6  Armando Bacot    SR   F  North Carolina  37  1123  380   56  22  ...
# 8    8  Reece Beekman    SR   G        Virginia  34  1114  124  212  68  ...
# 10  10     Chris Bell    SO   F        Syracuse  32   865   75   21  18  ...
#
# 0  TOV   PF  PTS    FG%    2P%    3P%    FT%   PER   WS   BPM
# 3   30   51  164  0.435  0.522  0.147   0.62   9.4  0.9  -1.3
# 5   13   35  216  0.417  0.563  0.295  0.737    18  2.9   7.9
# 6   60  100  538   0.54  0.544    0.4  0.781  24.6  6.1   8.9
# 8   70   43  486  0.443  0.487   0.31  0.754  23.4  4.9  10.5
# 10  26   58  384  0.434  0.459   0.42  0.842  14.9  2.2   3.3
#
# [5 rows x 21 columns]

# %%
#with new df, player with highest number of total assists (AST)

new_df["AST"] = pd.to_numeric(new_df["AST"])

total_assists = new_df[['Player', 'AST']].sort_values(by='AST', ascending=False).head(1)
total_assists
# Out:
# <ipython-input-12-5b62e2087d68>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["AST"] = pd.to_numeric(new_df["AST"])
# 0         Player  AST
# 8  Reece Beekman  212

# %%
#top 3 assist leads in the league

three_assistsLeads = new_df[['Player', 'AST']].sort_values(by='AST', ascending=False).head(3)
three_assistsLeads
# Out:
# 0            Player  AST
# 8     Reece Beekman  212
# 216  Jaeden Zackery  152
# 22    Elliot Cadeau  150

# %%
#top 3 shot blockers
new_df["BLK"] = pd.to_numeric(new_df["BLK"])


shot_blockers = new_df[['Player', 'BLK']].sort_values(by='BLK', ascending=False).head(3)
shot_blockers
# Out:
# <ipython-input-14-b8bcacf1a44d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["BLK"] = pd.to_numeric(new_df["BLK"])
# 0           Player  BLK
# 52       Ryan Dunn   77
# 158   Quinten Post   61
# 6    Armando Bacot   56

# %%
#Group the players by school and calculate the total points scored by each school

new_df["PTS"] = pd.to_numeric(new_df["PTS"])
# Out:
# <ipython-input-15-1161f991c987>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["PTS"] = pd.to_numeric(new_df["PTS"])

# %%
total_points = new_df.groupby('School')[['PTS']].sum().reset_index()
total_points
# Out:
# 0           School   PTS
# 0   Boston College  2305
# 1          Clemson  2647
# 2             Duke  2518
# 3    Florida State  1893
# 4     Georgia Tech  2152
# 5       Louisville  1987
# 6       Miami (FL)  2179
# 7         NC State  2839
# 8   North Carolina  2639
# 9       Notre Dame  2019
# 10      Pittsburgh  2368
# 11        Syracuse  2183
# 12        Virginia  1673
# 13   Virginia Tech  2128
# 14     Wake Forest  2558

# %%
#groupby school and total assists

new_df["AST"] = pd.to_numeric(new_df["AST"])
total_assists = new_df.groupby('School')[['AST']].sum().reset_index()
# Out:
# <ipython-input-17-a0f9436c74dc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["AST"] = pd.to_numeric(new_df["AST"])

# %%
total_assists
# Out:
# 0           School  AST
# 0   Boston College  440
# 1          Clemson  494
# 2             Duke  494
# 3    Florida State  328
# 4     Georgia Tech  405
# 5       Louisville  335
# 6       Miami (FL)  413
# 7         NC State  502
# 8   North Carolina  491
# 9       Notre Dame  312
# 10      Pittsburgh  430
# 11        Syracuse  402
# 12        Virginia  415
# 13   Virginia Tech  417
# 14     Wake Forest  410

# %%
#sort total_points to get top 3

total_points.sort_values(by="PTS", ascending = False).head(3)
# Out:
# 0          School   PTS
# 7        NC State  2839
# 1         Clemson  2647
# 8  North Carolina  2639

# %%
#Extra Credit- create a bar chart showing the top 5 players by total points scored

top_scorers = acc_df[['Player', 'PTS']].sort_values(by='PTS', ascending=False).head(5)
top_scorers
# Out:
# 0           Player  PTS
# 43        RJ Davis  784
# 82        DJ Horne  677
# 71         PJ Hall  659
# 176  Hunter Sallis  613
# 81    Blake Hinson  609

# %%
#Plot top 5 using bar chat

import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize=(10,6))
sns.barplot(x='Player', y='PTS', data=top_scorers)
plt.title('Top 5 ACC scorers')
plt.show()

# %%
#correlation between FG% and WS

acc_df["FG%"] = pd.to_numeric(acc_df["FG%"])
acc_df["WS"] = pd.to_numeric(acc_df["WS"])

plt.figure(figsize=(10,6))
plt.scatter(acc_df["FG%"], acc_df["WS"])
plt.title('Correlation between Field Goal Percentage and Win Shares')
plt.xlabel("Field Goal Percentage")
plt.ylabel("Win Shares")
plt.show()

# %%
#find the correlation

correlation = acc_df["FG%"].corr(acc_df["WS"])
print(f"\nThe correlation is: {correlation}")
# Out:
# The correlation is: 0.4210663894199787

# %% [markdown]
# Reflection:
#
# 1. What did you learn about working with CSV files and pandas DataFrames in this assignment?
#
# Some of the skills I developed were filtering and manipulating data. To complete some of the questions I needed to create a new data frame that only included players who had scored over 500 points. Then using this data, I had to complete tasks and ensure that I was always using the correct data frame. I also had to become familiar with when to use groupby and when to use sort. This assignment taught me how to select specific columns from different data sets and then sort it to ensure I only outputted information that was relevant to the question. These skills can be applied to future projects because it is very rare that a task requires the entire dataset so being able to form conclusions about specific variables and understanding how to navigate the dataset is really important. It was also valuable to learn how to visualize the data and work with two different styles of graphs. Data visualization is always useful in data science projects to help the audience understand the project and to be able to demonstrate the  relationships between variables.
#
# 2. What was the most challenging aspect of this assignment and how did you overcome it?
#
# The most challenging aspect of this assignment for me was to understand why I was getting an error when I tried to complete the question about outputting the total number of points scored by all players. When I ran my code it would output each value in one line instead of adding them up even though I was using the sum function. I had worked with strings in a previous class about a year ago, so I had temporarily forgotten about how to change data types. Once I changed the values in the points column to numeric values, I was able to use the sum function to add them together successfully. To address this problem I tried different variations of the code to see if I had made a spelling error or used the wrong dataset. Usually when I get an error, I assume it is something that I coded incorrectly so after I tried a few strategies I read the error and realized it was a problem with the data type. This was definitely a lesson to read the error first because I may actually know the solution. I had to change the data type for other variables that I had assumed would already be numeric, so I encountered this problem a few times but overcame the challenge much faster each time. I also think that needing to change the data type helped me better understand the data because I looked more closely at the raw data to try to understand the variables before I changed the data type. In previous classes I have rarely looked at the raw data unless I was doing data cleaning, but it was helpful to see all of the variables and the general type of values for each column.
#
# 3. How do you think the insights gained from analyzing ACC basketball statistics could be applied to other real-world datasets?
#
# The insights gained from analyzing ACC basketball statistics can be applied to other sports teams. Sports teams are very focused on the amount of money they generate and part of this is due to the success of the players on the team. This dataset focused on individual statistics for each player so similar analysis could be done on other datasets to see how players do over time, if they consistently perform well, and what their strengths are based on their statistics. For example, someone could analyze skills individually and select players depending on what their team needs most. They could select good rebounders, blockers, or players with a lot of points or assists. This kind of analysis is very useful for recruiting and able to select players for specific skills. This kind of analysis can also be used for individual teams because it can demonstrate strengths and weaknesses and coaches can place emphasis on specific skills during training. Individual statistics are often recorded during each game by the coaches, so being able to use the whole dataset to have an overview of team success of failures could be crucial to future success. It can also act as a way to evaluate other teams to identify how the team should play against them. These types of analyses could apply to all sports teams because they are always recording how well individuals or teams are doing.
