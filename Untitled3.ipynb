# %% [markdown]
# <a href="https://colab.research.google.com/github/ToriStoner/ToriStoner/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import json
import requests

# %%
# API endpoint and parameters
url = "http://api.weatherstack.com/current"
params = {
    "access_key": "8047f607bfcf64ddfe447a793edb44a2",
    "query" : "New York"
}

# Send the request and get the response
response = requests.get(url, params=params)

# %%
weather_data = response.json()

# %%
df = pd.DataFrame(weather_data)
print(df)
# Out:
#                                                  request  \
# type                                                City
# query                 New York, United States of America
# language                                              en
# unit                                                   m
# name                                                 NaN
# country                                              NaN
# region                                               NaN
# lat                                                  NaN
# lon                                                  NaN
# timezone_id                                          NaN
# localtime                                            NaN
# localtime_epoch                                      NaN
# utc_offset                                           NaN
# observation_time                                     NaN
# temperature                                          NaN
# ...

# %%
#convert dataframe to csv

df.to_csv("weather_data.csv")

weather_csv = pd.read_csv('weather_data.csv')

weather_csv.head()
# Out:
#   Unnamed: 0                             request  location current
# 0       type                                City       NaN     NaN
# 1      query  New York, United States of America       NaN     NaN
# 2   language                                  en       NaN     NaN
# 3       unit                                   m       NaN     NaN
# 4       name                                 NaN  New York     NaN

# %%
crime_df = pd.read_csv("/Crime_Data.csv")

# %%
crime_df.head()
# Out:
#    RecordID                          Offense    IncidentID  BlockNumber  \
# 0         1  Assist Citizen - Mental/TDO/ECO  202400034093        900.0
# 1         2    Larceny - Of Veh Parts/Access  202400034075       1600.0
# 2         3                      Hit and Run  202400034071        900.0
# 3         4               Disorderly Conduct  202400034068        900.0
# 4         5               Lost/FoundProperty  202400034047        700.0
#
#         StreetName Agency            DateReported  HourReported  \
# 0   ELLIOTT AVE, A    CPD  2024/10/02 00:24:02+00          2024
# 1    6TH ST SE, 28    CPD  2024/10/01 21:38:47+00          1738
# 2       EMMET ST N    CPD  2024/10/01 21:11:45+00          1711
# 3  ST CLAIR AVE, A    CPD  2024/10/01 20:59:17+00          1659
# 4         RUGBY RD    CPD  2024/10/01 18:23:15+00          1423
#
#   ReportingOfficer
# 0  Venereo, Arturo
# 1     Kirby, Tyree
# 2    Bland, Johnnà
# 3  Prevost, Payten
# 4   Brannon, Devin

# %%
#convert csv to Json

crime_df.to_json("crime_data.json")

# %%
#convert the Json to SQL
